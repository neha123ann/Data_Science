# %% [markdown]
# # Assignment 1

# %% [markdown]
# Do the following operation on Iris dataset:

# %% [markdown]
# 1. Read the dataset to python environment

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_excel(r'Downloads\iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# 2. Display the columns in the dataset.

# %%
data_columns= data.columns

# %%
data_columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# 3. Calculate the mean of each column of the dataset

# %%
mean_value = data.mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_11820\1936372058.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   mean_value = data.mean()

# %%
mean_value
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# 4. Check for the null values present in the dataset.

# %%
Null_value= data.isnull()

# %%
Null_value.sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# 5. Perform meaningful visualizations using the dataset. Bring at least 3
# visualizations.

# %% [markdown]
#    Visualization 1

# %%
sns.pairplot(data, hue='Classification')
plt.title('Iris Dataset')
plt.show()

# %% [markdown]
#  Visualization 2

# %%
sns.boxplot(x='Classification', y='SL', data=data)
plt.title('SL by Classification')
plt.show()

# %% [markdown]
# Visualization 3

# %%
sns.histplot(data, x='PL', hue='Classification', kde=True)
plt.title('PL by Classification')
plt.xlabel('PL')
plt.ylabel('Count')
plt.show()
